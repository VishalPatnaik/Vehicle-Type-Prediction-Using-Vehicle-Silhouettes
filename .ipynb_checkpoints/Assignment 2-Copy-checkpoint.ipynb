# %% [markdown]
# # Data Pre - Processing
#
# ### Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Loading Data

# %%
vehicle = pd.read_csv("Group_99.csv", encoding = "unicode_escape")# Loading the data using pandas function.
print(vehicle.shape)# gives the dimentions of the data frame.
vehicle# Displays the data in the data frame.
# Out:
# (846, 19)
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95.0         48.0                  83.0         178.0
# 1           91.0         41.0                  84.0         141.0
# 2          104.0         50.0                 106.0         209.0
# 3           93.0         41.0                  82.0         159.0
# 4           85.0         44.0                  70.0         205.0
# ..           ...          ...                   ...           ...
# 841         93.0         39.0                  87.0         183.0
# 842         89.0         46.0                  84.0         163.0
# 843        106.0         54.0                 101.0         222.0
# 844         86.0         36.0                  78.0         146.0
# 845         85.0         36.0                  66.0         123.0
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0               72.000000                10.000000          162.0
# 1               57.000000                 9.000000          149.0
# 2               66.000000                10.000000          207.0
# 3               63.000000                 9.000000          144.0
# 4               61.693853                 8.567376          149.0
# ..                    ...                      ...            ...
# 841             64.000000                 8.000000          169.0
# 842             66.000000                11.000000          159.0
# 843             67.000000                12.000000          222.0
# 844             58.000000                 7.000000          135.0
# 845             55.000000                 5.000000          120.0
#
#      ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42.0                    20.0                      159.0
# 1             45.0                    19.0                      143.0
# 2             32.0                    23.0                      158.0
# 3             46.0                    19.0                      143.0
# 4             45.0                    19.0                      144.0
# ..             ...                     ...                        ...
# 841           40.0                    20.0                      134.0
# 842           43.0                    20.0                      159.0
# 843           30.0                    25.0                      173.0
# 844           50.0                    18.0                      124.0
# 845           56.0                    17.0                      128.0
#
#      SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                    176.0                  379.0                      184.0
# 1                    170.0                  330.0                      158.0
# 2                    223.0                  635.0                      220.0
# 3                    160.0                  309.0                      127.0
# 4                    241.0                  325.0                      188.0
# ..                     ...                    ...                        ...
# 841                  200.0                  422.0                      149.0
# 842                  173.0                  368.0                      176.0
# 843                  228.0                  721.0                      200.0
# 844                  155.0                  270.0                      148.0
# 845                  140.0                  212.0                      131.0
#
#      SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0               70.000000                   6.0                  16.0
# 1               72.000000                   9.0                  14.0
# 2               73.000000                  14.0                   9.0
# 3               63.000000                   6.0                  10.0
# 4               72.462175                   9.0                  11.0
# ..                    ...                   ...                   ...
# 841             72.000000                   7.0                  25.0
# 842             72.000000                   1.0                  20.0
# 843             70.000000                   3.0                   4.0
# 844             66.000000                   0.0                  25.0
# 845             73.000000                   1.0                  18.0
#
#      KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO Class
# 0                   187.0          197.0   VAN
# 1                   189.0          199.0   VAN
# 2                   188.0          196.0  SAAB
# 3                   199.0          207.0   VAN
# 4                   180.0          183.0   BUS
# ..                    ...            ...   ...
# 841                 188.0          195.0  SAAB
# 842                 186.0          197.0   VAN
# 843                 187.0          201.0  SAAB
# 844                 190.0          195.0  SAAB
# 845                 186.0          190.0   VAN
#
# [846 rows x 19 columns]

# %%
vehicle.isnull().sum()
# Out:
# COMPACTNESS                  0
# CIRCULARITY                  0
# DISTANCE_CIRCULARITY         0
# RADIUS_RATIO                 0
# PR.AXIS_ASPECT_RATIO         0
# MAX.LENGTH_ASPECT_RATIO      0
# SCATTER_RATIO                0
# ELONGATEDNESS                0
# PR.AXIS_RECTANGULARITY       0
# MAX.LENGTH_RECTANGULARITY    0
# SCALED_VARIANCE_MAJOR        0
# SCALED_VARIANCE_MINOR        0
# SCALED_RADIUS_OF_GYRATION    0
# SKEWNESS_ABOUT_MAJOR         0
# SKEWNESS_ABOUT_MINOR         0
# KURTOSIS_ABOUT_MAJOR         0
# KURTOSIS_ABOUT_MINOR         0
# HOLLOWS_RATIO                0
# Class                        0
# dtype: int64

# %%
vehicle.describe(include = 'all')
# Out:
#         COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# count    846.000000   846.000000            846.000000    846.000000
# unique          NaN          NaN                   NaN           NaN
# top             NaN          NaN                   NaN           NaN
# freq            NaN          NaN                   NaN           NaN
# mean      93.678487    44.861702             82.088652    168.404046
# std        8.234474     6.169866             15.771533     32.222517
# min       73.000000    33.000000             40.000000    104.000000
# 25%       87.000000    40.000000             70.000000    141.000000
# 50%       93.000000    44.000000             80.000000    167.000000
# 75%      100.000000    49.000000             98.000000    195.000000
# max      119.000000    59.000000            112.000000    252.000000
#
#         PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# count             846.000000               846.000000     846.000000
# unique                   NaN                      NaN            NaN
# top                      NaN                      NaN            NaN
# freq                     NaN                      NaN            NaN
# mean               61.177956                 8.126922     168.839243
# std                 5.623709                 2.064796      33.244978
# min                47.000000                 3.000000     112.000000
# 25%                57.000000                 7.000000     146.250000
# 50%                61.000000                 8.000000     157.000000
# 75%                65.000000                10.000000     198.000000
# max                76.000000                13.000000     265.000000
#
#         ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# count      846.000000              846.000000                 846.000000
# unique            NaN                     NaN                        NaN
# top               NaN                     NaN                        NaN
# freq              NaN                     NaN                        NaN
# mean        40.933806               20.582742                 147.998818
# std          7.811560                2.592138                  14.515652
# min         26.000000               17.000000                 118.000000
# 25%         33.000000               19.000000                 137.000000
# 50%         43.000000               20.000000                 146.000000
# 75%         46.000000               23.000000                 159.000000
# max         61.000000               29.000000                 188.000000
#
#         SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  \
# count              846.000000             846.000000
# unique                    NaN                    NaN
# top                       NaN                    NaN
# freq                      NaN                    NaN
# mean               188.470006             438.568348
# std                 31.067449             174.511867
# min                130.000000             184.000000
# 25%                167.000000             318.250000
# 50%                178.500000             364.000000
# 75%                217.000000             586.000000
# max                288.000000             987.000000
#
#         SCALED_RADIUS_OF_GYRATION  SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  \
# count                   846.00000            846.000000            846.000000
# unique                        NaN                   NaN                   NaN
# top                           NaN                   NaN                   NaN
# freq                          NaN                   NaN                   NaN
# mean                    174.70331             71.979826              6.168469
# std                      32.54649              6.182516              4.589891
# min                     109.00000             59.000000              0.000000
# 25%                     149.00000             67.000000              2.000000
# 50%                     173.00000             71.500000              6.000000
# 75%                     198.00000             75.000000              9.000000
# max                     268.00000             87.000000             19.000000
#
#         KURTOSIS_ABOUT_MAJOR  KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO Class
# count             846.000000            846.000000     846.000000   846
# unique                   NaN                   NaN            NaN     4
# top                      NaN                   NaN            NaN   BUS
# freq                     NaN                   NaN            NaN   218
# mean               12.565720            188.932624     195.632388   NaN
# std                 8.877577              6.163949       7.438797   NaN
# min                 0.000000            176.000000     181.000000   NaN
# 25%                 5.000000            184.000000     190.250000   NaN
# 50%                11.000000            188.000000     197.000000   NaN
# 75%                19.000000            193.000000     201.000000   NaN
# max                40.000000            206.000000     211.000000   NaN

# %% [markdown]
# ## Data Modelling

# %% [markdown]
# ### Data Preparation
# Data is to be prepared for modelling as follows,

# %%
class_labels = ['Class']

v_class = vehicle[class_labels]
print(v_class)

v_levels = vehicle.drop(class_labels, axis = 1)
np.unique(vehicle["Class"])
# Out:
#     Class
# 0     VAN
# 1     VAN
# 2    SAAB
# 3     VAN
# 4     BUS
# ..    ...
# 841  SAAB
# 842   VAN
# 843  SAAB
# 844  SAAB
# 845   VAN
#
# [846 rows x 1 columns]
# array(['BUS', 'OPEL', 'SAAB', 'VAN'], dtype=object)

# %%
cor = vehicle.corr()
cor
# Out:
#                            COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  \
# COMPACTNESS                   1.000000     0.692869              0.792444
# CIRCULARITY                   0.692869     1.000000              0.798492
# DISTANCE_CIRCULARITY          0.792444     0.798492              1.000000
# RADIUS_RATIO                  0.723690     0.640334              0.798885
# PR.AXIS_ASPECT_RATIO          0.194120     0.198033              0.247936
# MAX.LENGTH_ASPECT_RATIO       0.496374     0.551695              0.662816
# SCATTER_RATIO                 0.813003     0.860367              0.907280
# ELONGATEDNESS                -0.788647    -0.828755             -0.912307
# PR.AXIS_RECTANGULARITY        0.813437     0.857925              0.895326
# MAX.LENGTH_RECTANGULARITY     0.676143     0.965776              0.774524
# SCALED_VARIANCE_MAJOR         0.772275     0.815282              0.872618
# SCALED_VARIANCE_MINOR         0.813114     0.846928              0.889346
# SCALED_RADIUS_OF_GYRATION     0.585347     0.936080              0.705818
# SKEWNESS_ABOUT_MAJOR         -0.252462     0.076645             -0.238116
# SKEWNESS_ABOUT_MINOR          0.196192     0.141703              0.102440
# KURTOSIS_ABOUT_MAJOR          0.156200    -0.013819              0.261581
# KURTOSIS_ABOUT_MINOR          0.297780    -0.113047              0.147980
# HOLLOWS_RATIO                 0.365552     0.038677              0.335453
#
#                            RADIUS_RATIO  PR.AXIS_ASPECT_RATIO  \
# COMPACTNESS                    0.723690              0.194120
# CIRCULARITY                    0.640334              0.198033
# DISTANCE_CIRCULARITY           0.798885              0.247936
# RADIUS_RATIO                   1.000000              0.655298
# PR.AXIS_ASPECT_RATIO           0.655298              1.000000
# MAX.LENGTH_ASPECT_RATIO        0.463333              0.151661
# SCATTER_RATIO                  0.773839              0.196388
# ELONGATEDNESS                 -0.828351             -0.300153
# PR.AXIS_RECTANGULARITY         0.747107              0.162723
# MAX.LENGTH_RECTANGULARITY      0.580776              0.150950
# SCALED_VARIANCE_MAJOR          0.790874              0.211223
# SCALED_VARIANCE_MINOR          0.768333              0.198124
# SCALED_RADIUS_OF_GYRATION      0.553562              0.152091
# SKEWNESS_ABOUT_MAJOR          -0.390778             -0.319682
# SKEWNESS_ABOUT_MINOR           0.038550             -0.053523
# KURTOSIS_ABOUT_MAJOR           0.180281             -0.024534
# KURTOSIS_ABOUT_MINOR           0.404146              0.397315
# HOLLOWS_RATIO                  0.489518              0.414271
#
#                            MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# COMPACTNESS                               0.496374       0.813003
# CIRCULARITY                               0.551695       0.860367
# DISTANCE_CIRCULARITY                      0.662816       0.907280
# RADIUS_RATIO                              0.463333       0.773839
# PR.AXIS_ASPECT_RATIO                      0.151661       0.196388
# MAX.LENGTH_ASPECT_RATIO                   1.000000       0.488688
# SCATTER_RATIO                             0.488688       1.000000
# ELONGATEDNESS                            -0.501254      -0.973385
# PR.AXIS_RECTANGULARITY                    0.485760       0.992088
# MAX.LENGTH_RECTANGULARITY                 0.642076       0.810648
# SCALED_VARIANCE_MAJOR                     0.404833       0.963976
# SCALED_VARIANCE_MINOR                     0.462941       0.986937
# SCALED_RADIUS_OF_GYRATION                 0.396888       0.800932
# SKEWNESS_ABOUT_MAJOR                     -0.335955       0.008194
# SKEWNESS_ABOUT_MINOR                      0.080852       0.064478
# KURTOSIS_ABOUT_MAJOR                      0.140436       0.210026
# KURTOSIS_ABOUT_MINOR                      0.078230       0.004053
# HOLLOWS_RATIO                             0.410668       0.119950
#
#                            ELONGATEDNESS  PR.AXIS_RECTANGULARITY  \
# COMPACTNESS                    -0.788647                0.813437
# CIRCULARITY                    -0.828755                0.857925
# DISTANCE_CIRCULARITY           -0.912307                0.895326
# RADIUS_RATIO                   -0.828351                0.747107
# PR.AXIS_ASPECT_RATIO           -0.300153                0.162723
# MAX.LENGTH_ASPECT_RATIO        -0.501254                0.485760
# SCATTER_RATIO                  -0.973385                0.992088
# ELONGATEDNESS                   1.000000               -0.950512
# PR.AXIS_RECTANGULARITY         -0.950512                1.000000
# MAX.LENGTH_RECTANGULARITY      -0.775531                0.813305
# SCALED_VARIANCE_MAJOR          -0.949604                0.951209
# SCALED_VARIANCE_MINOR          -0.953745                0.981187
# SCALED_RADIUS_OF_GYRATION      -0.766146                0.798282
# SKEWNESS_ABOUT_MAJOR            0.082089                0.024915
# SKEWNESS_ABOUT_MINOR           -0.047995                0.072088
# KURTOSIS_ABOUT_MAJOR           -0.183917                0.212306
# KURTOSIS_ABOUT_MINOR           -0.112046               -0.022056
# HOLLOWS_RATIO                  -0.216725                0.098519
#
#                            MAX.LENGTH_RECTANGULARITY  SCALED_VARIANCE_MAJOR  \
# COMPACTNESS                                 0.676143               0.772275
# CIRCULARITY                                 0.965776               0.815282
# DISTANCE_CIRCULARITY                        0.774524               0.872618
# RADIUS_RATIO                                0.580776               0.790874
# PR.AXIS_ASPECT_RATIO                        0.150950               0.211223
# MAX.LENGTH_ASPECT_RATIO                     0.642076               0.404833
# SCATTER_RATIO                               0.810648               0.963976
# ELONGATEDNESS                              -0.775531              -0.949604
# PR.AXIS_RECTANGULARITY                      0.813305               0.951209
# MAX.LENGTH_RECTANGULARITY                   1.000000               0.752612
# SCALED_VARIANCE_MAJOR                       0.752612               1.000000
# SCALED_VARIANCE_MINOR                       0.795025               0.951269
# SCALED_RADIUS_OF_GYRATION                   0.866479               0.787301
# SKEWNESS_ABOUT_MAJOR                        0.051763               0.025214
# SKEWNESS_ABOUT_MINOR                        0.132780               0.028087
# KURTOSIS_ABOUT_MAJOR                        0.003798               0.194792
# KURTOSIS_ABOUT_MINOR                       -0.107718               0.012064
# HOLLOWS_RATIO                               0.076770               0.086194
#
#                            SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# COMPACTNESS                             0.813114                   0.585347
# CIRCULARITY                             0.846928                   0.936080
# DISTANCE_CIRCULARITY                    0.889346                   0.705818
# RADIUS_RATIO                            0.768333                   0.553562
# PR.AXIS_ASPECT_RATIO                    0.198124                   0.152091
# MAX.LENGTH_ASPECT_RATIO                 0.462941                   0.396888
# SCATTER_RATIO                           0.986937                   0.800932
# ELONGATEDNESS                          -0.953745                  -0.766146
# PR.AXIS_RECTANGULARITY                  0.981187                   0.798282
# MAX.LENGTH_RECTANGULARITY               0.795025                   0.866479
# SCALED_VARIANCE_MAJOR                   0.951269                   0.787301
# SCALED_VARIANCE_MINOR                   1.000000                   0.788264
# SCALED_RADIUS_OF_GYRATION               0.788264                   1.000000
# SKEWNESS_ABOUT_MAJOR                    0.004658                   0.214983
# SKEWNESS_ABOUT_MINOR                    0.065994                   0.164942
# KURTOSIS_ABOUT_MAJOR                    0.206960                  -0.055778
# KURTOSIS_ABOUT_MINOR                    0.015363                  -0.227366
# HOLLOWS_RATIO                           0.120343                  -0.117808
#
#                            SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  \
# COMPACTNESS                           -0.252462              0.196192
# CIRCULARITY                            0.076645              0.141703
# DISTANCE_CIRCULARITY                  -0.238116              0.102440
# RADIUS_RATIO                          -0.390778              0.038550
# PR.AXIS_ASPECT_RATIO                  -0.319682             -0.053523
# MAX.LENGTH_ASPECT_RATIO               -0.335955              0.080852
# SCATTER_RATIO                          0.008194              0.064478
# ELONGATEDNESS                          0.082089             -0.047995
# PR.AXIS_RECTANGULARITY                 0.024915              0.072088
# MAX.LENGTH_RECTANGULARITY              0.051763              0.132780
# SCALED_VARIANCE_MAJOR                  0.025214              0.028087
# SCALED_VARIANCE_MINOR                  0.004658              0.065994
# SCALED_RADIUS_OF_GYRATION              0.214983              0.164942
# SKEWNESS_ABOUT_MAJOR                   1.000000             -0.064645
# SKEWNESS_ABOUT_MINOR                  -0.064645              1.000000
# KURTOSIS_ABOUT_MAJOR                  -0.124857             -0.046310
# KURTOSIS_ABOUT_MINOR                  -0.840976              0.089561
# HOLLOWS_RATIO                         -0.907050              0.065900
#
#                            KURTOSIS_ABOUT_MAJOR  KURTOSIS_ABOUT_MINOR  \
# COMPACTNESS                            0.156200              0.297780
# CIRCULARITY                           -0.013819             -0.113047
# DISTANCE_CIRCULARITY                   0.261581              0.147980
# RADIUS_RATIO                           0.180281              0.404146
# PR.AXIS_ASPECT_RATIO                  -0.024534              0.397315
# MAX.LENGTH_ASPECT_RATIO                0.140436              0.078230
# SCATTER_RATIO                          0.210026              0.004053
# ELONGATEDNESS                         -0.183917             -0.112046
# PR.AXIS_RECTANGULARITY                 0.212306             -0.022056
# MAX.LENGTH_RECTANGULARITY              0.003798             -0.107718
# SCALED_VARIANCE_MAJOR                  0.194792              0.012064
# SCALED_VARIANCE_MINOR                  0.206960              0.015363
# SCALED_RADIUS_OF_GYRATION             -0.055778             -0.227366
# SKEWNESS_ABOUT_MAJOR                  -0.124857             -0.840976
# SKEWNESS_ABOUT_MINOR                  -0.046310              0.089561
# KURTOSIS_ABOUT_MAJOR                   1.000000              0.076456
# KURTOSIS_ABOUT_MINOR                   0.076456              1.000000
# HOLLOWS_RATIO                          0.200886              0.894098
#
#                            HOLLOWS_RATIO
# COMPACTNESS                     0.365552
# CIRCULARITY                     0.038677
# DISTANCE_CIRCULARITY            0.335453
# RADIUS_RATIO                    0.489518
# PR.AXIS_ASPECT_RATIO            0.414271
# MAX.LENGTH_ASPECT_RATIO         0.410668
# SCATTER_RATIO                   0.119950
# ELONGATEDNESS                  -0.216725
# PR.AXIS_RECTANGULARITY          0.098519
# MAX.LENGTH_RECTANGULARITY       0.076770
# SCALED_VARIANCE_MAJOR           0.086194
# SCALED_VARIANCE_MINOR           0.120343
# SCALED_RADIUS_OF_GYRATION      -0.117808
# SKEWNESS_ABOUT_MAJOR           -0.907050
# SKEWNESS_ABOUT_MINOR            0.065900
# KURTOSIS_ABOUT_MAJOR            0.200886
# KURTOSIS_ABOUT_MINOR            0.894098
# HOLLOWS_RATIO                   1.000000

# %%
from sklearn import preprocessing

# %% [markdown]
# The data is not on an standard scale and need to be standardised.

# %%
min_max_scaler = preprocessing.MinMaxScaler()
v_levels[:] = min_max_scaler.fit_transform(v_levels[:])
v_levels
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0       0.478261     0.576923              0.597222      0.500000
# 1       0.391304     0.307692              0.611111      0.250000
# 2       0.673913     0.653846              0.916667      0.709459
# 3       0.434783     0.307692              0.583333      0.371622
# 4       0.260870     0.423077              0.416667      0.682432
# ..           ...          ...                   ...           ...
# 841     0.434783     0.230769              0.652778      0.533784
# 842     0.347826     0.500000              0.611111      0.398649
# 843     0.717391     0.807692              0.847222      0.797297
# 844     0.282609     0.115385              0.527778      0.283784
# 845     0.260870     0.115385              0.361111      0.128378
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                0.862069                 0.700000       0.326797
# 1                0.344828                 0.600000       0.241830
# 2                0.655172                 0.700000       0.620915
# 3                0.551724                 0.600000       0.209150
# 4                0.506685                 0.556738       0.241830
# ..                    ...                      ...            ...
# 841              0.586207                 0.500000       0.372549
# 842              0.655172                 0.800000       0.307190
# 843              0.689655                 0.900000       0.718954
# 844              0.379310                 0.400000       0.150327
# 845              0.275862                 0.200000       0.052288
#
#      ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0         0.457143                0.250000                   0.585714
# 1         0.542857                0.166667                   0.357143
# 2         0.171429                0.500000                   0.571429
# 3         0.571429                0.166667                   0.357143
# 4         0.542857                0.166667                   0.371429
# ..             ...                     ...                        ...
# 841       0.400000                0.250000                   0.228571
# 842       0.485714                0.250000                   0.585714
# 843       0.114286                0.666667                   0.785714
# 844       0.685714                0.083333                   0.085714
# 845       0.857143                0.000000                   0.142857
#
#      SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                 0.291139               0.242839                   0.471698
# 1                 0.253165               0.181818                   0.308176
# 2                 0.588608               0.561644                   0.698113
# 3                 0.189873               0.155666                   0.113208
# 4                 0.702532               0.175592                   0.496855
# ..                     ...                    ...                        ...
# 841               0.443038               0.296389                   0.251572
# 842               0.272152               0.229141                   0.421384
# 843               0.620253               0.668742                   0.572327
# 844               0.158228               0.107098                   0.245283
# 845               0.063291               0.034869                   0.138365
#
#      SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                0.392857              0.315789                 0.400
# 1                0.464286              0.473684                 0.350
# 2                0.500000              0.736842                 0.225
# 3                0.142857              0.315789                 0.250
# 4                0.480792              0.473684                 0.275
# ..                    ...                   ...                   ...
# 841              0.464286              0.368421                 0.625
# 842              0.464286              0.052632                 0.500
# 843              0.392857              0.157895                 0.100
# 844              0.250000              0.000000                 0.625
# 845              0.500000              0.052632                 0.450
#
#      KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO
# 0                0.366667       0.533333
# 1                0.433333       0.600000
# 2                0.400000       0.500000
# 3                0.766667       0.866667
# 4                0.133333       0.066667
# ..                    ...            ...
# 841              0.400000       0.466667
# 842              0.333333       0.533333
# 843              0.366667       0.666667
# 844              0.466667       0.466667
# 845              0.333333       0.300000
#
# [846 rows x 18 columns]

# %% [markdown]
# ### Feature Selection using Random forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 100)
forest.fit(v_levels, v_class.values.ravel())
# Out:
# RandomForestClassifier()

# %% [markdown]
# ### Feature Importance Table based on CLASS

# %%
def feature_importance_report_tree(clf, features):
    feature_importances = zip(features, clf.feature_importances_)
    rows = []
    for f, imp in sorted(feature_importances, key = lambda x : x[1], reverse = True):
        rows.append([f, imp])
    v_rep = pd.DataFrame(rows, columns = ['Feature', 'Relative_Importance'])
    return v_rep

# %%
Class_imp_for = feature_importance_report_tree(forest, v_levels.columns)
Class_imp_for = Class_imp_for.rename(columns={"Relative_Importance": "Class_Importance"})
Class_imp_for["Class_rank"] = Class_imp_for["Class_Importance"].rank(ascending = 0) 
Class_imp_for
# Out:
#                       Feature  Class_Importance  Class_rank
# 0     MAX.LENGTH_ASPECT_RATIO          0.117855         1.0
# 1       SCALED_VARIANCE_MINOR          0.089284         2.0
# 2       SCALED_VARIANCE_MAJOR          0.069932         3.0
# 3               ELONGATEDNESS          0.069682         4.0
# 4   MAX.LENGTH_RECTANGULARITY          0.069152         5.0
# 5               SCATTER_RATIO          0.065489         6.0
# 6        DISTANCE_CIRCULARITY          0.061963         7.0
# 7                 COMPACTNESS          0.056211         8.0
# 8               HOLLOWS_RATIO          0.054225         9.0
# 9        PR.AXIS_ASPECT_RATIO          0.052431        10.0
# 10       SKEWNESS_ABOUT_MAJOR          0.047905        11.0
# 11  SCALED_RADIUS_OF_GYRATION          0.041724        12.0
# 12                CIRCULARITY          0.040132        13.0
# 13       KURTOSIS_ABOUT_MAJOR          0.037219        14.0
# 14               RADIUS_RATIO          0.034859        15.0
# 15       KURTOSIS_ABOUT_MINOR          0.033415        16.0
# 16       SKEWNESS_ABOUT_MINOR          0.032490        17.0
# 17     PR.AXIS_RECTANGULARITY          0.026032        18.0

# %%
# %config InlineBackend.figure_format = 'retina'
plt.style.use("ggplot")

def plot_imp(best_features, scores, method_name):
    df = pd.DataFrame({'features' : best_features, 'importances' : scores})
    fig, ax = plt.subplots(figsize=(15, 5))
    g = sns.barplot(ax = ax, x = "features", y = "importances", data = df)
    g.set_xticklabels(ax.get_xticklabels(), rotation = 70)

# %%
plot_imp(Class_imp_for["Feature"], Class_imp_for["Class_Importance"], 'Random Forest')

# %%
from sklearn.model_selection import train_test_split

X_train, x_test, \
y_train, y_test = train_test_split(v_levels.values, v_class.values.ravel(), 
                                                    test_size = 0.3, random_state = 999,
                                                    stratify = v_class)

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn import metrics
from sklearn.metrics import precision_recall_curve, classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, make_scorer, recall_score, precision_score, roc_auc_score

v_cross_val = StratifiedKFold(n_splits = 5, random_state = 999, shuffle = True)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# custom function for RFI feature selection inside a pipeline
# here we use n_estimators=100
class RFIFeatureSelector(BaseEstimator, TransformerMixin):
    
    # class constructor 
    # make sure class attributes end with a "_"
    # per scikit-learn convention to avoid errors
    def __init__(self, n_features_=10):
        self.n_features_ = n_features_
        self.fs_indices_ = None

    # override the fit function
    def fit(self, X, y):
        from sklearn.ensemble import RandomForestClassifier
        from numpy import argsort
        model_rfi = RandomForestClassifier(n_estimators=100)
        model_rfi.fit(X, y)
        self.fs_indices_ = argsort(model_rfi.feature_importances_)[::-1][0:self.n_features_] 
        return self 
    
    # override the transform function
    def transform(self, X, y=None):
        return X[:, self.fs_indices_]

# %%
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier

pipe_KNN = Pipeline(steps=[('rfi_fs', RFIFeatureSelector()), 
                           ('knn', KNeighborsClassifier())])

params_pipe_KNN = {'rfi_fs__n_features_': [10, 18, X_train.shape[1]],
                   'knn__n_neighbors': [1, 5, 10, 15],
                   'knn__p': [1]}

gs_pipe_KNN = GridSearchCV(estimator=pipe_KNN, 
                           param_grid=params_pipe_KNN, 
                           cv=v_cross_val,
                           refit=True,
                           #n_jobs=-2,
                           n_jobs=None,
                           pre_dispatch='2*n_jobs',
                           #scoring='accuracy',
                           verbose=1)

# %%
gs_pipe_KNN.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
gs_pipe_KNN.best_params_
# Out:
# {'knn__n_neighbors': 5, 'knn__p': 1, 'rfi_fs__n_features_': 18}

# %%
gs_pipe_KNN.best_score_
# Out:
# 0.729682381427147

# %%
def get_search_results(gs):

    def model_result(scores, params):
        scores = {'mean_score': np.mean(scores),
             'std_score': np.std(scores),
             'min_score': np.min(scores),
             'max_score': np.max(scores)}
        return pd.Series({**params,**scores})

    models = []
    scores = []

    for i in range(gs.n_splits_):
        key = f"split{i}_test_score"
        r = gs.cv_results_[key]        
        scores.append(r.reshape(-1,1))

    all_scores = np.hstack(scores)
    for p, s in zip(gs.cv_results_['params'], all_scores):
        models.append((model_result(s, p)))

    pipe_results = pd.concat(models, axis=1).T.sort_values(['mean_score'], ascending=False)

    columns_first = ['mean_score', 'std_score', 'max_score', 'min_score']
    columns = columns_first + [c for c in pipe_results.columns if c not in columns_first]

    return pipe_results[columns]

# %%
results_KNN = get_search_results(gs_pipe_KNN)
results_KNN.head()
# Out:
#    mean_score  std_score  max_score  min_score  knn__n_neighbors  knn__p  \
# 4    0.729682   0.032940   0.762712   0.669492               5.0     1.0
# 5    0.729682   0.032940   0.762712   0.669492               5.0     1.0
# 6    0.716209   0.015717   0.739496   0.697479              10.0     1.0
# 7    0.716180   0.037611   0.754237   0.644068              10.0     1.0
# 8    0.716180   0.037611   0.754237   0.644068              10.0     1.0
#
#    rfi_fs__n_features_
# 4                 18.0
# 5                 18.0
# 6                 10.0
# 7                 18.0
# 8                 18.0

# %%
results_KNN_10_features = results_KNN[results_KNN['rfi_fs__n_features_'] == 10.0]

for i in results_KNN_10_features['knn__p'].unique():
    temp = results_KNN_10_features[results_KNN_10_features['knn__p'] == i]
    plt.plot(temp['knn__n_neighbors'], temp['mean_score'], marker = '.', label = i)
    
plt.legend(title = "p")
plt.xlabel('Number of Neighbors')
plt.ylabel("AUC Score")
plt.title("KNN Performance Comparison with 10 Features")
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.preprocessing import PowerTransformer
X_train_transformed = PowerTransformer().fit_transform(X_train)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import RandomizedSearchCV

pipe_NB = Pipeline([('rfi_fs', RFIFeatureSelector()), 
                     ('nb', GaussianNB())])

params_pipe_NB = {'rfi_fs__n_features_': [10, 15, X_train.shape[1]],
                  'nb__var_smoothing': np.logspace(1,-3, num=200)}

n_iter_search = 20

gs_pipe_NB = GridSearchCV(estimator=pipe_NB, 
                           param_grid=params_pipe_NB, 
                           cv=v_cross_val,
                           refit=True,
                           #n_jobs=-2,
                           n_jobs=None,
                           pre_dispatch='2*n_jobs',
                           #scoring='accuracy',
                           verbose=1)

# %%
gs_pipe_NB.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 600 candidates, totalling 3000 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=999, shuffle=True),
#              estimator=Pipeline(steps=[('rfi_fs', RFIFeatureSelector()),
#                                        ('nb', GaussianNB())]),
#              param_grid={'nb__var_smoothing': array([1.00000000e+01, 9.54771611e+00, 9.11588830e+00, 8.70359136e+00,
#        8.30994195e+00, 7.93409667e+00, 7.57525026e+00, 7.23263390e+00,
#        6.90551352e+00, 6.59318827e+00, 6.29498...
#        2.89942285e-03, 2.76828663e-03, 2.64308149e-03, 2.52353917e-03,
#        2.40940356e-03, 2.30043012e-03, 2.19638537e-03, 2.09704640e-03,
#        2.00220037e-03, 1.91164408e-03, 1.82518349e-03, 1.74263339e-03,
#        1.66381689e-03, 1.58856513e-03, 1.51671689e-03, 1.44811823e-03,
#        1.38262217e-03, 1.32008840e-03, 1.26038293e-03, 1.20337784e-03,
#        1.14895100e-03, 1.09698580e-03, 1.04737090e-03, 1.00000000e-03]),
#                          'rfi_fs__n_features_': [10, 15, 18]},
#              verbose=1)

# %%
gs_pipe_NB.best_params_
# Out:
# {'nb__var_smoothing': 10.0, 'rfi_fs__n_features_': 10}

# %%
gs_pipe_NB.best_score_
# Out:
# 0.5337986041874376

# %%
results_NB = get_search_results(gs_pipe_NB)
results_NB.head()
# Out:
#      mean_score  std_score  max_score  min_score  nb__var_smoothing  \
# 0      0.533799   0.043382   0.593220   0.474576          10.000000
# 487    0.533756   0.027310   0.571429   0.500000           0.005543
# 577    0.532032   0.036715   0.596639   0.491525           0.001383
# 439    0.530380   0.029364   0.571429   0.491525           0.011623
# 472    0.530366   0.024869   0.571429   0.500000           0.006986
#
#      rfi_fs__n_features_
# 0                   10.0
# 487                 15.0
# 577                 15.0
# 439                 15.0
# 472                 15.0

# %%
results_NB_10_features = results_NB[results_NB['rfi_fs__n_features_'] == 10.0].sort_values('nb__var_smoothing')

plt.plot(results_NB_10_features['nb__var_smoothing'], results_NB_10_features['mean_score'], marker = '.', label = i)    
plt.xlabel('Var. Smoothing')
plt.ylabel("AUC Score")
plt.title("NB Performance Comparison with 10 Features")
plt.show()

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

# %%
pipe_SVM = Pipeline([('rfi_fs', RFIFeatureSelector()), 
                     ('SVM', SVC())])

params_pipe_SVM = {'rfi_fs__n_features_': [10, 15, X_train.shape[1]],
                  'SVM__C':[0.001,0.1,10,100,10e5], 'SVM__gamma':[0.1,0.01]}

n_iter_search = 20

gs_pipe_SVM = GridSearchCV(estimator=pipe_SVM, 
                           param_grid=params_pipe_SVM, 
                           cv=v_cross_val,
                           refit=True,
                           #n_jobs=-2,
                           n_jobs=None,
                           pre_dispatch='2*n_jobs',
                           #scoring='accuracy',
                           verbose=1)

# %%
gs_pipe_SVM.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=999, shuffle=True),
#              estimator=Pipeline(steps=[('rfi_fs', RFIFeatureSelector()),
#                                        ('SVM', SVC())]),
#              param_grid={'SVM__C': [0.001, 0.1, 10, 100, 1000000.0],
#                          'SVM__gamma': [0.1, 0.01],
#                          'rfi_fs__n_features_': [10, 15, 18]},
#              verbose=1)

# %%
gs_pipe_SVM.best_params_
# Out:
# {'SVM__C': 1000000.0, 'SVM__gamma': 0.01, 'rfi_fs__n_features_': 15}

# %%
gs_pipe_SVM.best_score_
# Out:
# 0.8243412619285003

# %%
results_SVM = get_search_results(gs_pipe_SVM)
results_SVM.head()
# Out:
#     mean_score  std_score  max_score  min_score     SVM__C  SVM__gamma  \
# 28    0.824341   0.019445   0.855932   0.796610  1000000.0        0.01
# 29    0.819185   0.030492   0.848739   0.771186  1000000.0        0.01
# 19    0.804031   0.031926   0.840336   0.754237      100.0        0.10
# 20    0.803945   0.032392   0.857143   0.762712      100.0        0.10
# 26    0.792223   0.008746   0.805085   0.779661  1000000.0        0.10
#
#     rfi_fs__n_features_
# 28                 15.0
# 29                 18.0
# 19                 15.0
# 20                 18.0
# 26                 18.0

# %%
results_SVM_10_features = results_SVM[results_SVM['rfi_fs__n_features_'] == 10.0].sort_values('SVM__C')

plt.plot(results_SVM_10_features['SVM__C'], results_SVM_10_features['mean_score'], marker = '.', label = i)    
plt.xlabel('Var. Smoothing')
plt.ylabel("AUC Score")
plt.title("SVM Performance Comparison with 10 Features")
plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
pipe_DT = Pipeline([('rfi_fs', RFIFeatureSelector()),
                    ('dt', DecisionTreeClassifier(criterion='gini', random_state=111))])

params_pipe_DT = {'rfi_fs__n_features_': [10, 15, X_train.shape[1]],
                  'dt__max_depth': [3, 4, 5],
                  'dt__min_samples_split': [2, 5]}

gs_pipe_DT = GridSearchCV(estimator=pipe_DT, 
                           param_grid=params_pipe_DT, 
                           cv=v_cross_val,
                           refit=True,
                           #n_jobs=-2,
                           #n_jobs=None,
                           pre_dispatch='2*n_jobs',
                           #scoring='accuracy',
                           verbose=1)

# %%
pipe_DT.get_params()
# Out:
# {'memory': None,
#  'steps': [('rfi_fs', RFIFeatureSelector()),
#   ('dt', DecisionTreeClassifier(random_state=111))],
#  'verbose': False,
#  'rfi_fs': RFIFeatureSelector(),
#  'dt': DecisionTreeClassifier(random_state=111),
#  'rfi_fs__n_features_': 10,
#  'dt__ccp_alpha': 0.0,
#  'dt__class_weight': None,
#  'dt__criterion': 'gini',
#  'dt__max_depth': None,
#  'dt__max_features': None,
#  'dt__max_leaf_nodes': None,
#  'dt__min_impurity_decrease': 0.0,
#  'dt__min_impurity_split': None,
#  'dt__min_samples_leaf': 1,
#  'dt__min_samples_split': 2,
#  'dt__min_weight_fraction_leaf': 0.0,
#  'dt__random_state': 111,
#  'dt__splitter': 'best'}

# %%
gs_pipe_DT.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits

# %%
gs_pipe_DT.best_params_
# Out:
# {'dt__max_depth': 4, 'dt__min_samples_split': 5, 'rfi_fs__n_features_': 10}

# %%
gs_pipe_DT.best_score_
# Out:
# 0.6654322746047572

# %%
results_DT = get_search_results(gs_pipe_DT)
results_DT_10_features = results_DT[results_DT['rfi_fs__n_features_'] == 10.0]


for i in results_DT_10_features['dt__max_depth'].unique():
    temp = results_DT_10_features[results_DT_10_features['dt__max_depth'] == i]
    plt.plot(temp['dt__min_samples_split'], temp['mean_score'], marker = '.', label = i)
    
plt.legend(title = "Max Depth")
plt.xlabel('Min Samples for Split')
plt.ylabel("AUC Score")
plt.title("DT Performance Comparison with 10 Features")
plt.show()

# %% [markdown]
# ## Further tuning

# %%
params_pipe_DT2 = {'rfi_fs__n_features_': [10],
                  'dt__max_depth': [5, 10, 15],
                  'dt__min_samples_split': [5, 50, 100, 150]}

gs_pipe_DT2 = GridSearchCV(estimator=pipe_DT, 
                           param_grid=params_pipe_DT2, 
                           cv=v_cross_val,
                           refit=True,
                           #n_jobs=-2,
                           n_jobs=None,
                           pre_dispatch='n_jobs',
                           #scoring='accuracy',
                           verbose=1)

# %%
gs_pipe_DT2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
gs_pipe_DT2.best_params_
# Out:
# {'dt__max_depth': 10, 'dt__min_samples_split': 5, 'rfi_fs__n_features_': 10}

# %%
gs_pipe_DT2.best_score_
# Out:
# 0.6841333143426862

# %%
results_DT = get_search_results(gs_pipe_DT2)
results_DT.head()
# Out:
#     mean_score  std_score  max_score  min_score  dt__max_depth  \
# 4     0.684133   0.028993   0.720339   0.635593           10.0
# 6     0.675559   0.036302   0.722689   0.618644           10.0
# 10    0.675559   0.036302   0.722689   0.618644           15.0
# 2     0.673864   0.035951   0.722689   0.618644            5.0
# 8     0.670474   0.034175   0.714286   0.627119           15.0
#
#     dt__min_samples_split  rfi_fs__n_features_
# 4                     5.0                 10.0
# 6                   100.0                 10.0
# 10                  100.0                 10.0
# 2                   100.0                 10.0
# 8                     5.0                 10.0

# %%
results_DT_10_features = results_DT[results_DT['rfi_fs__n_features_'] == 10.0].sort_values('dt__min_samples_split')


for i in results_DT_10_features['dt__max_depth'].unique():
    temp = results_DT_10_features[results_DT_10_features['dt__max_depth'] == i]
    plt.plot(temp['dt__min_samples_split'], temp['mean_score'], marker = '.', label = i)
    
plt.legend(title = "Max Depth")
plt.xlabel('Min Samples for Split')
plt.ylabel("AUC Score")
plt.title("DT Performance Comparison with 10 Features - Extended")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
pipe_LR = Pipeline([('rfi_fs', RFIFeatureSelector()),
                    ('logistic', LogisticRegression())])

params_pipe_LR = {'rfi_fs__n_features_': [10, 15, X_train.shape[1]],
                  'logistic__C': np.logspace(-4, 4, 4)}

gs_pipe_LR = GridSearchCV(estimator=pipe_LR, 
                           param_grid=params_pipe_LR, 
                           cv=v_cross_val,
                           refit=True,
                           #n_jobs=-2,
                           n_jobs=None,
                           pre_dispatch='2*n_jobs',
                           #scoring='accuracy',
                           verbose=1)

# %%
gs_pipe_LR.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
gs_pipe_LR.best_params_
# Out:
# {'logistic__C': 10000.0, 'rfi_fs__n_features_': 18}

# %%
gs_pipe_LR.best_score_
# Out:
# 0.7803304372596497

# %%
results_LR = get_search_results(gs_pipe_LR)
results_LR.head()
# Out:
#     mean_score  std_score  max_score  min_score   logistic__C  \
# 11    0.780330   0.022744   0.806723   0.745763  10000.000000
# 10    0.778636   0.037576   0.840336   0.728814  10000.000000
# 8     0.763424   0.029489   0.798319   0.720339     21.544347
# 7     0.761758   0.024789   0.781513   0.720339     21.544347
# 6     0.711138   0.031319   0.756303   0.672269     21.544347
#
#     rfi_fs__n_features_
# 11                 18.0
# 10                 15.0
# 8                  18.0
# 7                  15.0
# 6                  10.0

# %% [markdown]
# # Performance Comparison

# %%
from sklearn.model_selection import cross_val_score

cv_method_ttest = StratifiedKFold(n_splits = 10)

cv_results_KNN = cross_val_score(estimator = gs_pipe_KNN.best_estimator_,
                                 X = x_test,
                                 y = y_test, 
                                 cv = v_cross_val)
cv_results_KNN.mean()
# Out:
# 0.6533333333333334

# %%
x_test_transformed = PowerTransformer().fit_transform(x_test)

cv_results_NB = cross_val_score(estimator = gs_pipe_NB.best_estimator_,
                                 X = x_test_transformed,
                                 y = y_test, 
                                 cv = v_cross_val)
cv_results_NB.mean()
# Out:
# 0.519843137254902

# %%
cv_results_SVM = cross_val_score(estimator = gs_pipe_SVM.best_estimator_,
                                 X = x_test,
                                 y = y_test, 
                                 cv = v_cross_val)
cv_results_SVM.mean()
# Out:
# 0.7438431372549019

# %%
cv_results_DT2 = cross_val_score(estimator = gs_pipe_DT2.best_estimator_,
                                 X = x_test,
                                 y = y_test, 
                                 cv = v_cross_val)
cv_results_DT2.mean()
# Out:
# 0.6101960784313726

# %%
cv_results_LR = cross_val_score(estimator = gs_pipe_LR.best_estimator_,
                                 X = x_test,
                                 y = y_test, 
                                 cv = v_cross_val)
cv_results_LR.mean()
# Out:
# 0.7279215686274509

# %%
from scipy import stats

print(stats.ttest_rel(cv_results_KNN, cv_results_NB))
print(stats.ttest_rel(cv_results_DT2, cv_results_KNN))
print(stats.ttest_rel(cv_results_KNN, cv_results_SVM))
print(stats.ttest_rel(cv_results_LR, cv_results_KNN))
print(stats.ttest_rel(cv_results_DT2, cv_results_SVM))
print(stats.ttest_rel(cv_results_DT2, cv_results_NB))
print(stats.ttest_rel(cv_results_DT2, cv_results_LR))
print(stats.ttest_rel(cv_results_SVM, cv_results_NB))
print(stats.ttest_rel(cv_results_SVM, cv_results_LR))
print(stats.ttest_rel(cv_results_NB, cv_results_LR))
# Out:
# Ttest_relResult(statistic=3.0690139738397804, pvalue=0.03732882558144152)
# Ttest_relResult(statistic=-1.6678156958735884, pvalue=0.17067830985568666)
# Ttest_relResult(statistic=-3.483941274544825, pvalue=0.025261381809738727)
# Ttest_relResult(statistic=3.571530281219502, pvalue=0.023343760566057373)
# Ttest_relResult(statistic=-3.2067373455969754, pvalue=0.03269029571081173)
# Ttest_relResult(statistic=2.114370186608624, pvalue=0.10198682970698614)
# Ttest_relResult(statistic=-2.968781124409464, pvalue=0.04119403093588505)
# Ttest_relResult(statistic=6.492820998420963, pvalue=0.0029018809842632286)
# Ttest_relResult(statistic=0.9355335406557888, pvalue=0.4024772811668352)
# Ttest_relResult(statistic=-4.786914025409065, pvalue=0.008731242370740367)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn import metrics

def run_classifier(clf, class_labels):
    
    y_pred = clf.predict(x_test)
    
    class_names = set(v_class[class_labels].values)    
    
    print('Accuracy on Training data: ', round(clf.score(X_train, y_train), 2))
    
    print('Accuracy on Testing data: ', round(clf.score(x_test_transformed , y_test), 2))

    print('Recall value: ', round(metrics.recall_score(y_test, y_pred, average ='macro'), 2))

    print('Precision value: ', round(metrics.precision_score(y_test, y_pred, average ='macro'), 2))
    
    print('Classification Report: \n', classification_report(y_test, y_pred))

# %%
run_classifier(gs_pipe_KNN, 'Class')
# Out:
# Accuracy on Training data:  0.82
# Accuracy on Testing data:  0.37
# Recall value:  0.69
# Precision value:  0.68
# Classification Report:
#                precision    recall  f1-score   support
#
#          BUS       0.84      0.98      0.91        65
#         OPEL       0.47      0.44      0.45        64
#         SAAB       0.51      0.48      0.49        65
#          VAN       0.89      0.85      0.87        60
#
#     accuracy                           0.69       254
#    macro avg       0.68      0.69      0.68       254
# weighted avg       0.67      0.69      0.68       254

# %%
y_pred = gs_pipe_NB.predict(x_test)
    
class_names = set(v_class['Class'].values)    
print('Accuracy on Training data: ', round(gs_pipe_NB.score(X_train_transformed, y_train), 2))
print('Accuracy on Testing data: ', round(gs_pipe_NB.score(x_test_transformed , y_test), 2))
print('Recall value: ', round(metrics.recall_score(y_test, y_pred, average ='macro'), 2))
print('Precision value: ', round(metrics.precision_score(y_test, y_pred, average ='macro'), 2))
print('Classification Report: ', classification_report(y_test, y_pred))
# Out:
# Accuracy on Training data:  0.59
# Accuracy on Testing data:  0.59
# Recall value:  0.59
# Precision value:  0.63
# Classification Report:                precision    recall  f1-score   support
#
#          BUS       0.80      0.51      0.62        65
#         OPEL       0.58      0.28      0.38        64
#         SAAB       0.65      0.55      0.60        65
#          VAN       0.47      1.00      0.64        60
#
#     accuracy                           0.58       254
#    macro avg       0.63      0.59      0.56       254
# weighted avg       0.63      0.58      0.56       254

# %%
run_classifier(gs_pipe_SVM, 'Class')
# Out:
# Accuracy on Training data:  0.92
# Accuracy on Testing data:  0.59
# Recall value:  0.79
# Precision value:  0.79
# Classification Report:
#                precision    recall  f1-score   support
#
#          BUS       0.93      1.00      0.96        65
#         OPEL       0.62      0.70      0.66        64
#         SAAB       0.67      0.60      0.63        65
#          VAN       0.94      0.85      0.89        60
#
#     accuracy                           0.79       254
#    macro avg       0.79      0.79      0.79       254
# weighted avg       0.79      0.79      0.79       254

# %%
run_classifier(gs_pipe_DT2, 'Class')
# Out:
# Accuracy on Training data:  0.94
# Accuracy on Testing data:  0.42
# Recall value:  0.72
# Precision value:  0.71
# Classification Report:
#                precision    recall  f1-score   support
#
#          BUS       0.91      0.98      0.95        65
#         OPEL       0.56      0.56      0.56        64
#         SAAB       0.53      0.48      0.50        65
#          VAN       0.84      0.87      0.85        60
#
#     accuracy                           0.72       254
#    macro avg       0.71      0.72      0.72       254
# weighted avg       0.71      0.72      0.71       254

# %%
run_classifier(gs_pipe_LR, 'Class')
# Out:
# Accuracy on Training data:  0.82
# Accuracy on Testing data:  0.65
# Recall value:  0.83
# Precision value:  0.82
# Classification Report:
#                precision    recall  f1-score   support
#
#          BUS       0.94      1.00      0.97        65
#         OPEL       0.73      0.67      0.70        64
#         SAAB       0.68      0.66      0.67        65
#          VAN       0.92      0.97      0.94        60
#
#     accuracy                           0.82       254
#    macro avg       0.82      0.83      0.82       254
# weighted avg       0.82      0.82      0.82       254

# %%
def plot_confusion_matrix(clf, y_test, classes,
                          title = 'Confusion matrix',
                          cmap = plt.cm.Blues, normalize=True):
    
    y_pred = clf.predict(x_test)
   
    cm = confusion_matrix(y_test, y_pred)
    np.set_printoptions(precision = 2)

    plt.figure()
    fig, ax = plt.subplots(figsize = (9, 7.2))
    plt.rcParams.update({'font.size': 15})
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)
    cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, "{0:.3f}".format(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    plt.show()
    
    classification_error_rate = 1.0 * sum(1 for (x, y) in zip(y_test, y_pred) if x != y) / len(list(y_test))
    print('Classification Error Rate: ', classification_error_rate)

# %%
plot_confusion_matrix(gs_pipe_KNN, y_test, np.unique(v_class))
# Out:
# Classification Error Rate:  0.31496062992125984

# %%
plot_confusion_matrix(gs_pipe_NB, y_test, np.unique(v_class))
# Out:
# Classification Error Rate:  0.421259842519685

# %%
plot_confusion_matrix(gs_pipe_SVM, y_test, np.unique(v_class))
# Out:
# Classification Error Rate:  0.2125984251968504

# %%
plot_confusion_matrix(gs_pipe_DT2, y_test, np.unique(v_class))
# Out:
# Classification Error Rate:  0.2795275590551181

# %%
plot_confusion_matrix(gs_pipe_LR, y_test, np.unique(v_class))
# Out:
# Classification Error Rate:  0.17716535433070865

# %%
Model_Accuracy = pd.DataFrame({'Model' : [ 'Naive_Bayes', 'SVM', 'KNN', 'Decision_Tree', 'Logistic Regression'], 
                               'Train_Accuracy' : [round(gs_pipe_NB.score(X_train_transformed, y_train)*100, 2),
                                                   round(gs_pipe_SVM.score(X_train, y_train)*100, 2),
                                                   round(gs_pipe_KNN.score(X_train, y_train)*100, 2),
                                                   round(gs_pipe_DT2.score(X_train, y_train)*100, 2),
                                                   round(gs_pipe_LR.score(X_train, y_train)*100, 2)],
                               'Test_Accuracy' : [round(gs_pipe_NB.score(x_test_transformed, y_test)*100, 2),
                                                  round(gs_pipe_SVM.score(x_test, y_test)*100, 2),
                                                  round(gs_pipe_KNN.score(x_test, y_test)*100, 2),
                                                  round(gs_pipe_DT2.score(x_test, y_test)*100, 2),
                                                  round(gs_pipe_LR.score(X_train, y_train)*100, 2)]})

Model_Accuracy
# Out:
#                  Model  Train_Accuracy  Test_Accuracy
# 0          Naive_Bayes           59.46          58.66
# 1                  SVM           92.23          78.74
# 2                  KNN           81.93          68.50
# 3        Decision_Tree           94.26          72.05
# 4  Logistic Regression           82.26          82.26
